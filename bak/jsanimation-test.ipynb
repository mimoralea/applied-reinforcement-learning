# %%
# The typical imports
import gym
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# Imports specifically so we can render outputs in Jupyter.
from JSAnimation.IPython_display import display_animation
from matplotlib import animation
from IPython.display import display


def display_frames_as_gif(frames):
    """
    Displays a list of frames as a gif, with controls
    """
    #plt.figure(figsize=(frames[0].shape[1] / 72.0, frames[0].shape[0] / 72.0), dpi = 72)
    patch = plt.imshow(frames[0])
    plt.axis('off')

    def animate(i):
        patch.set_data(frames[i])

    anim = animation.FuncAnimation(plt.gcf(), animate, frames = len(frames), interval=50)
    display(display_animation(anim, default_mode='loop'))

# %%
env = gym.make('CartPole-v0')

# Run a demo of the environment
observation = env.reset()
cum_reward = 0
frames = []
for t in range(5000):
    # Render into buffer. 
    frames.append(env.render(mode = 'rgb_array'))
    action = env.action_space.sample()
    observation, reward, done, info = env.step(action)
    if done:
        break
env.render(close=True)
display_frames_as_gif(frames)
# Out:
# [2017-03-17 17:13:50,731] Making new env: CartPole-v0
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src = this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_forward();}, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_reverse();}, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgIXFCFHQSSJZBKVRM">
#     <br>
#     <input id="_anim_sliderIXFCFHQSSJZBKVRM" type="range" style="width:350px" name="points" min="0" max="1" step="1" value="0" onchange="animIXFCFHQSSJZBKVRM.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animIXFCFHQSSJZBKVRM.slower()">&#8211;</button>
#     <button onclick="animIXFCFHQSSJZBKVRM.first_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animIXFCFHQSSJZBKVRM.previous_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animIXFCFHQSSJZBKVRM.reverse_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animIXFCFHQSSJZBKVRM.pause_animation()"><img class="anim_icon" src="..."></button>
#     <button onclick="animIXFCFHQSSJZBKVRM.play_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animIXFCFHQSSJZBKVRM.next_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animIXFCFHQSSJZBKVRM.last_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animIXFCFHQSSJZBKVRM.faster()">+</button>
#   <form action="#n" name="_anim_loop_selectIXFCFHQSSJZBKVRM" class="anim_control">
#     <input type="radio" name="state" value="once" > Once </input>
#     <input type="radio" name="state" value="loop" checked> Loop </input>
#     <input type="radio" name="state" value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgIXFCFHQSSJZBKVRM";
#     var slider_id = "_anim_sliderIXFCFHQSSJZBKVRM";
#     var loop_select_id = "_anim_loop_selectIXFCFHQSSJZBKVRM";
#     var frames = new Array(0);
#
#   frames[0] = "data:image/png;base64,..."
#   frames[1] = "data:image/png;base64,..."
#   frames[2] = "data:image/png;base64,..."
#   frames[3] = "data:image/png;base64,..."
#   frames[4] = "data:image/png;base64,..."
#   frames[5] = "data:image/png;base64,..."
#   frames[6] = "data:image/png;base64,..."
#   frames[7] = "data:image/png;base64,..."
#   frames[8] = "data:image/png;base64,..."
#   frames[9] = "data:image/png;base64,..."
#   frames[10] = "data:image/png;base64,..."
#   frames[11] = "data:image/png;base64,..."
#   frames[12] = "data:image/png;base64,..."
#   frames[13] = "data:image/png;base64,..."
#   frames[14] = "data:image/png;base64,..."
#   frames[15] = "data:image/png;base64,..."
#   frames[16] = "data:image/png;base64,..."
#   frames[17] = "data:image/png;base64,..."
#   frames[18] = "data:image/png;base64,..."
#   frames[19] = "data:image/png;base64,..."
#   frames[20] = "data:image/png;base64,..."
#
#
#     /* set a timeout to make sure all the above elements are created before
#        the object is initialized. */
#     setTimeout(function() {
#         animIXFCFHQSSJZBKVRM = new Animation(frames, img_id, slider_id, 50, loop_select_id);
#     }, 0);
#   })()
# </script>

# %%
env = gym.make('CartPole-v0')
cum_reward = 0
frames = []
num_episodes=40
for i_episode in range(num_episodes):
    observation = env.reset()
    for t in range(500):
        # Render into buffer. 
        frames.append(env.render(mode = 'rgb_array'))
        action = env.action_space.sample() # random action
        observation, reward, done, info = env.step(action)
        if done:
            print("\rEpisode {}/{} finished after {} timesteps".format(i_episode, num_episodes, t+1), end="")
            break
env.render(close=True)
display_frames_as_gif(frames)
# Out:
# [2017-03-17 16:01:53,324] Making new env: CartPole-v0
# Episode 39/40 finished after 28 timesteps
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src = this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_forward();}, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_reverse();}, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgTJWUYSLTKEDLAHVD">
#     <br>
#     <input id="_anim_sliderTJWUYSLTKEDLAHVD" type="range" style="width:350px" name="points" min="0" max="1" step="1" value="0" onchange="animTJWUYSLTKEDLAHVD.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animTJWUYSLTKEDLAHVD.slower()">&#8211;</button>
#     <button onclick="animTJWUYSLTKEDLAHVD.first_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animTJWUYSLTKEDLAHVD.previous_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animTJWUYSLTKEDLAHVD.reverse_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animTJWUYSLTKEDLAHVD.pause_animation()"><img class="anim_icon" src="..."></button>
#     <button onclick="animTJWUYSLTKEDLAHVD.play_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animTJWUYSLTKEDLAHVD.next_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animTJWUYSLTKEDLAHVD.last_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animTJWUYSLTKEDLAHVD.faster()">+</button>
#   <form action="#n" name="_anim_loop_selectTJWUYSLTKEDLAHVD" class="anim_control">
#     <input type="radio" name="state" value="once" > Once </input>
#     <input type="radio" name="state" value="loop" checked> Loop </input>
#     <input type="radio" name="state" value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgTJWUYSLTKEDLAHVD";
#     var slider_id = "_anim_sliderTJWUYSLTKEDLAHVD";
#     var loop_select_id = "_anim_loop_selectTJWUYSLTKEDLAHVD";
#     var frames = new Array(0);
#
#   frames[0] = "data:image/png;base64,..."
#   frames[1] = "data:image/png;base64,..."
#   frames[2] = "data:image/png;base64,..."
#   frames[3] = "data:image/png;base64,..."
#   frames[4] = "data:image/png;base64,..."
#   frames[5] = "data:image/png;base64,..."
#   frames[6] = "data:image/png;base64,..."
#   frames[7] = "data:image/png;base64,..."
#   frames[8] = "data:image/png;base64,..."
#   frames[9] = "data:image/png;base64,..."
#   frames[10] = "data:image/png;base64,..."
#   frames[11] = "data:image/png;base64,..."
#   frames[12] = "data:image/png;base64,..."
#   frames[13] = "data:image/png;base64,..."
#   frames[14] = "data:image/png;base64,..."
#   frames[15] = "data:image/png;base64,..."
#   frames[16] = "data:image/png;base64,..."
#   frames[17] = "data:image/png;base64,..."
#   frames[18] = "data:image/png;base64,..."
#   frames[19] = "data:image/png;base64,..."
#   frames[20] = "data:image/png;base64,..."
#   frames[21] = "data:image/png;base64,..."
#   frames[22] = "data:image/png;base64,..."
#   frames[23] = "data:image/png;base64,..."
#   frames[24] = "data:image/png;base64,..."
#   frames[25] = "data:image/png;base64,..."
#   frames[26] = "data:image/png;base64,..."
#   frames[27] = "data:image/png;base64,..."
#   frames[28] = "data:image/png;base64,..."
#   frames[29] = "data:image/png;base64,..."
#   frames[30] = "data:image/png;base64,..."
#   frames[31] = "data:image/png;base64,..."
#   frames[32] = "data:image/png;base64,..."
#   frames[33] = "data:image/png;base64,..."
#   frames[34] = "data:image/png;base64,..."
#   frames[35] = "data:image/png;base64,..."
#   frames[36] = "data:image/png;base64,..."
#   frames[37] = "data:image/png;base64,..."
#   frames[38] = "data:image/png;base64,..."
#   frames[39] = "data:image/png;base64,..."
#   frames[40] = "data:image/png;base64,..."
#   frames[41] = "data:image/png;base64,..."
#   frames[42] = "data:image/png;base64,..."
#   frames[43] = "data:image/png;base64,..."
#   frames[44] = "data:image/png;base64,..."
#   frames[45] = "data:image/png;base64,..."
#   frames[46] = "data:image/png;base64,..."
#   frames[47] = "data:image/png;base64,..."
#   frames[48] = "data:image/png;base64,..."
#   frames[49] = "data:image/png;base64,..."
#   frames[50] = "data:image/png;base64,..."
#   frames[51] = "data:image/png;base64,..."
#   frames[52] = "data:image/png;base64,..."
#   frames[53] = "data:image/png;base64,..."
#   frames[54] = "data:image/png;base64,..."
#   frames[55] = "data:image/png;base64,..."
#   frames[56] = "data:image/png;base64,..."
#   frames[57] = "data:image/png;base6

# %%
from gym import envs
print(envs.registry.all())
# Out:
# dict_values([EnvSpec(IceHockey-ramDeterministic-v3), EnvSpec(Asterix-ramDeterministic-v0), EnvSpec(Pooyan-ram-v3), EnvSpec(Freeway-ramNoFrameskip-v0), EnvSpec(BeamRiderNoFrameskip-v3), EnvSpec(ChopperCommand-ramNoFrameskip-v3), EnvSpec(SkiingNoFrameskip-v0), EnvSpec(FishingDerby-ram-v0), EnvSpec(Berzerk-ramDeterministic-v0), EnvSpec(Venture-v0), EnvSpec(AirRaid-v3), EnvSpec(Carnival-ramDeterministic-v3), EnvSpec(StarGunner-ram-v0), EnvSpec(Pendulum-v0), EnvSpec(SpaceInvadersNoFrameskip-v0), EnvSpec(AssaultDeterministic-v0), EnvSpec(NameThisGame-ramDeterministic-v3), EnvSpec(NameThisGame-ram-v3), EnvSpec(DoubleDunk-ram-v0), EnvSpec(Gopher-ram-v3), EnvSpec(Berzerk-ramNoFrameskip-v0), EnvSpec(Boxing-ramNoFrameskip-v3), EnvSpec(SpaceInvaders-ramDeterministic-v0), EnvSpec(RobotankDeterministic-v0), EnvSpec(KrullDeterministic-v3), EnvSpec(FishingDerby-v3), EnvSpec(UpNDownDeterministic-v0), EnvSpec(Tutankham-ram-v0), EnvSpec(DemonAttackNoFrameskip-v0), EnvSpec(VideoPinball-ram-v0), EnvSpec(JamesbondNoFrameskip-v3), EnvSpec(AssaultDeterministic-v3), EnvSpec(JourneyEscape-ramDeterministic-v0), EnvSpec(FreewayDeterministic-v0), EnvSpec(GravitarNoFrameskip-v0), EnvSpec(NameThisGame-ramNoFrameskip-v3), EnvSpec(GravitarDeterministic-v0), EnvSpec(Atlantis-ramDeterministic-v0), EnvSpec(InvertedDoublePendulum-v1), EnvSpec(Freeway-ramDeterministic-v0), EnvSpec(Seaquest-ram-v3), EnvSpec(BankHeist-ramNoFrameskip-v3), EnvSpec(AmidarNoFrameskip-v3), EnvSpec(Gravitar-v3), EnvSpec(BattleZone-ramDeterministic-v0), EnvSpec(Jamesbond-ram-v0), EnvSpec(RoadRunnerDeterministic-v0), EnvSpec(Asterix-v3), EnvSpec(PooyanNoFrameskip-v3), EnvSpec(YarsRevenge-ramNoFrameskip-v3), EnvSpec(Zaxxon-ramDeterministic-v0), EnvSpec(Hopper-v1), EnvSpec(TimePilotDeterministic-v0), EnvSpec(Swimmer-v1), EnvSpec(Bowling-v0), EnvSpec(Breakout-ramDeterministic-v3), EnvSpec(JamesbondDeterministic-v3), EnvSpec(DuplicatedInput-v0), EnvSpec(Frostbite-ramDeterministic-v0), EnvSpec(QbertNoFrameskip-v0), EnvSpec(KungFuMaster-ramNoFrameskip-v3), EnvSpec(Tennis-v0), EnvSpec(Phoenix-ramDeterministic-v0), EnvSpec(DemonAttackNoFrameskip-v3), EnvSpec(DemonAttack-ramNoFrameskip-v0), EnvSpec(PrivateEye-ram-v3), EnvSpec(Breakout-ram-v0), EnvSpec(Enduro-ramDeterministic-v0), EnvSpec(FishingDerby-ramDeterministic-v3), EnvSpec(Boxing-ramNoFrameskip-v0), EnvSpec(Phoenix-ram-v0), EnvSpec(Freeway-v0), EnvSpec(PrivateEyeNoFrameskip-v0), EnvSpec(Jamesbond-ramDeterministic-v3), EnvSpec(PrivateEyeDeterministic-v3), EnvSpec(Pong-ramNoFrameskip-v3), EnvSpec(Pong-ram-v3), EnvSpec(NameThisGameNoFrameskip-v0), EnvSpec(StarGunnerNoFrameskip-v0), EnvSpec(DemonAttack-ramDeterministic-v3), EnvSpec(ChopperCommandNoFrameskip-v3), EnvSpec(JourneyEscape-ram-v3), EnvSpec(Gopher-v0), EnvSpec(Centipede-v3), EnvSpec(TimePilot-ram-v3), EnvSpec(BerzerkDeterministic-v3), EnvSpec(StarGunnerNoFrameskip-v3), EnvSpec(BowlingNoFrameskip-v0), EnvSpec(DemonAttack-ramNoFrameskip-v3), EnvSpec(DoubleDunk-v3), EnvSpec(TimePilotNoFrameskip-v0), EnvSpec(Pooyan-ram-v0), EnvSpec(GopherNoFrameskip-v0), EnvSpec(WizardOfWor-v0), EnvSpec(Amidar-ram-v0), EnvSpec(Atlantis-ram-v0), EnvSpec(Jamesbond-ramNoFrameskip-v0), EnvSpec(ZaxxonDeterministic-v3), EnvSpec(Tennis-ramDeterministic-v0), EnvSpec(Kangaroo-ram-v3), EnvSpec(Phoenix-ram-v3), EnvSpec(ElevatorActionNoFrameskip-v3), EnvSpec(KungFuMasterNoFrameskip-v3), EnvSpec(Atlantis-v3), EnvSpec(BipedalWalker-v2), EnvSpec(DoubleDunkDeterministic-v0), EnvSpec(MontezumaRevengeNoFrameskip-v0), EnvSpec(OneRoundNondeterministicReward-v0), EnvSpec(CarnivalDeterministic-v0), EnvSpec(BowlingDeterministic-v0), EnvSpec(ChopperCommandDeterministic-v0), EnvSpec(UpNDown-ram-v0), EnvSpec(Amidar-ramNoFrameskip-v3), EnvSpec(AirRaid-ram-v0), EnvSpec(BankHeistDeterministic-v0), EnvSpec(StarGunner-v3), EnvSpec(Alien-ramDeterministic-v3), EnvSpec(Carnival-ramNoFrameskip-v0), EnvSpec(SpaceInvadersNoFrameskip-v3), EnvSpec(UpNDown-ramNoFrameskip-v3), EnvSpec(UpNDown-v3), EnvSpec(Skiing-ramDeterministic-v0), EnvSpec(Frost ...
