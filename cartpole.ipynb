# %%
import gym
import pandas as pd
import numpy as np
import random

class QLearner(object):
    def __init__(self,
                 num_states=100,
                 num_actions=4,
                 alpha=0.2,
                 gamma=0.9,
                 random_action_rate=0.5,
                 random_action_decay_rate=0.99):
        self.num_states = num_states
        self.num_actions = num_actions
        self.alpha = alpha
        self.gamma = gamma
        self.random_action_rate = random_action_rate
        self.random_action_decay_rate = random_action_decay_rate
        self.state = 0
        self.action = 0
        self.qtable = np.random.uniform(low=-1, high=1, size=(num_states, num_actions))

    def set_initial_state(self, state):
        """
        @summary: Sets the initial state and returns an action
        @param state: The initial state
        @returns: The selected action
        """
        self.state = state
        self.action = self.qtable[state].argsort()[-1]
        return self.action

    def move(self, state_prime, reward):
        """
        @summary: Moves to the given state with given reward and returns action
        @param state_prime: The new state
        @param reward: The reward
        @returns: The selected action
        """
        alpha = self.alpha
        gamma = self.gamma
        state = self.state
        action = self.action
        qtable = self.qtable

        choose_random_action = (1 - self.random_action_rate) <= np.random.uniform(0, 1)

        if choose_random_action:
            action_prime = random.randint(0, self.num_actions - 1)
        else:
            action_prime = self.qtable[state_prime].argsort()[-1]

        self.random_action_rate *= self.random_action_decay_rate

        qtable[state, action] = (1 - alpha) * qtable[state, action] + alpha * (reward + gamma * qtable[state_prime, action_prime])

        self.state = state_prime
        self.action = action_prime

        return self.action


def cart_pole_with_qlearning():
    env = gym.make('CartPole-v0')
    experiment_filename = './cartpole-experiment-1'
    # env.monitor.start(experiment_filename, force=True)
    env = gym.wrappers.Monitor(env, experiment_filename, force=True)
    goal_average_steps = 195
    max_number_of_steps = 200
    number_of_iterations_to_average = 100

    number_of_features = env.observation_space.shape[0]
    last_time_steps = np.ndarray(0)

    cart_position_bins = pd.cut([-2.4, 2.4], bins=10, retbins=True)[1][1:-1]
    pole_angle_bins = pd.cut([-2, 2], bins=10, retbins=True)[1][1:-1]
    cart_velocity_bins = pd.cut([-1, 1], bins=10, retbins=True)[1][1:-1]
    angle_rate_bins = pd.cut([-3.5, 3.5], bins=10, retbins=True)[1][1:-1]

    def build_state(features):
        return int("".join(map(lambda feature: str(int(feature)), features)))

    def to_bin(value, bins):
        return np.digitize(x=[value], bins=bins)[0]

    learner = QLearner(num_states=10 ** number_of_features,
                       num_actions=env.action_space.n,
                       alpha=0.2,
                       gamma=1,
                       random_action_rate=0.5,
                       random_action_decay_rate=0.99)

    for episode in range(50000):
        observation = env.reset()
        cart_position, pole_angle, cart_velocity, angle_rate_of_change = observation
        state = build_state([to_bin(cart_position, cart_position_bins),
                             to_bin(pole_angle, pole_angle_bins),
                             to_bin(cart_velocity, cart_velocity_bins),
                             to_bin(angle_rate_of_change, angle_rate_bins)])
        action = learner.set_initial_state(state)
        
        while True:

            observation, reward, done, info = env.step(action)
            cart_position, pole_angle, cart_velocity, angle_rate_of_change = observation

            state_prime = build_state([to_bin(cart_position, cart_position_bins),
                                       to_bin(pole_angle, pole_angle_bins),
                                       to_bin(cart_velocity, cart_velocity_bins),
                                       to_bin(angle_rate_of_change, angle_rate_bins)])

            action = learner.move(state_prime, reward)

            if done:
                break
            state = state_prime

        if last_time_steps.mean() > goal_average_steps:
            print("Goal reached!")
            print("Episodes before solve: ", episode + 1)
            print(u"Best 100-episode performance {} {} {}".format(last_time_steps.max(),
                                                                  unichr(177),  # plus minus sign
                                                                  last_time_steps.std()))

    env.monitor.close()

if __name__ == "__main__":
    random.seed(0)
    cart_pole_with_qlearning()
# Out:
# [2017-03-18 13:31:54,192] Making new env: CartPole-v0
# [2017-03-18 13:31:54,195] Clearing 2 monitor files from previous run (because force=True was provided)
# [2017-03-18 13:31:54,200] Starting new video recorder writing to /home/mimoralea/Projects/applied-reinforcement-learning/cartpole-experiment-1/openaigym.video.6.16738.video000000.mp4
# /usr/local/lib/python3.5/dist-packages/ipykernel/__main__.py:119: RuntimeWarning: Mean of empty slice.
# /usr/local/lib/python3.5/dist-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# [2017-03-18 13:31:54,522] Starting new video recorder writing to /home/mimoralea/Projects/applied-reinforcement-learning/cartpole-experiment-1/openaigym.video.6.16738.video000001.mp4
# /usr/local/lib/python3.5/dist-packages/ipykernel/__main__.py:119: RuntimeWarning: Mean of empty slice.
# /usr/local/lib/python3.5/dist-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# [2017-03-18 13:31:54,883] Starting new video recorder writing to /home/mimoralea/Projects/applied-reinforcement-learning/cartpole-experiment-1/openaigym.video.6.16738.video000008.mp4
# /usr/local/lib/python3.5/dist-packages/ipykernel/__main__.py:119: RuntimeWarning: Mean of empty slice.
# /usr/local/lib/python3.5/dist-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# [2017-03-18 13:31:55,469] Starting new video recorder writing to /home/mimoralea/Projects/applied-reinforcement-learning/cartpole-experiment-1/openaigym.video.6.16738.video000027.mp4
# /usr/local/lib/python3.5/dist-packages/ipykernel/__main__.py:119: RuntimeWarning: Mean of empty slice.
# /usr/local/lib/python3.5/dist-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# [2017-03-18 13:31:55,730] Starting new video recorder writing to /home/mimoralea/Projects/applied-reinforcement-learning/cartpole-experiment-1/openaigym.video.6.16738.video000064.mp4
# /usr/local/lib/python3.5/dist-packages/ipykernel/__main__.py:119: RuntimeWarning: Mean of empty slice.
# /usr/local/lib/python3.5/dist-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# [2017-03-18 13:31:57,203] Starting new video recorder writing to /home/mimoralea/Projects/applied-reinforcement-learning/cartpole-experiment-1/openaigym.video.6.16738.video000125.mp4
# /usr/local/lib/python3.5/dist-packages/ipykernel/__main__.py:119: RuntimeWarning: Mean of empty slice.
# /usr/local/lib/python3.5/dist-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# [2017-03-18 13:31:59,194] Starting new video recorder writing to /home/mimoralea/Projects/applied-reinforcement-learning/cartpole-experiment-1/openaigym.video.6.16738.video000216.mp4
# /usr/local/lib/python3.5/dist-packages/ipykernel/__main__.py:119: RuntimeWarning: Mean of empty slice.
# /usr/local/lib/python3.5/dist-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# [2017-03-18 13:32:00,140] Starting new video recorder writing to /home/mimoralea/Projects/applied-reinforcement-learning/cartpole-experiment-1/openaigym.video.6.16738.video000343.mp4
# /usr/local/lib/python3.5/dist-packages/ipykernel/__main__.py:119: RuntimeWarning: Mean of empty slice.
# /usr/local/lib/python3.5/dist-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# [2017-03-18 13:32:01,136] Starting new video recorder writing to /home/mimoralea/Projects/applied-reinforcement-learning/cartpole-experiment-1/openaigym.video.6.16738.video000512.mp4
# /usr/local/lib/python3.5/dist-packages/ipykernel/__main__.py:119: RuntimeWarning: Mean of empty slice.
# /usr/local/lib/python3.5/dist-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# [2017-03-18 13:32:01,675] Starting new video recorder writing to /home/mimoralea/Projects/applied-reinforcement-learning/cartpole-experiment-1/openaigym.video.6.16738.video000729.mp4
# /usr/local/lib/python3.5/dist-packages/ipykernel/__main__.py:119: RuntimeWarning: Mean of empty slice.
# /usr/local/lib/python3.5/dist-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# [2017-03-18 13:32:02,780] Starting new video recorder writing to /home/mimoralea/Projects/applied-reinforcement-learning/cartpole-experiment-1/openaigym.video.6.16738.video001000.mp4
# /usr/local/lib/python3.5/dist-packages/ipykernel/__main__.py:119: RuntimeWarning: Mean of empty slice.
# /usr/local/lib/python3.5/dist-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# [2017-03-18 13:32:05,041] Starting new video recorder writing to /home/mimoralea/Projects/applied-reinforcement-learning/cartpole-experiment-1/openaigym.video.6.16738.video002000.mp4
# /usr/local/lib/python3.5/dist-packages/ipykernel/__main__.py:119: RuntimeWarning: Mean of empty slice.
# /usr/local/lib/python3.5/dist-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# [2017-03-18 13:32:07,174] Starting new video recorder writing to /home/mimoralea/Projects/applied-reinforcement-learning/cartpole-experiment-1/openaigym.video.6.16738.video003000.mp4
# /usr/local/lib/python3.5/dist-packages/ipykernel/__main__.py:119: RuntimeWarning: Mean of empty slice.
# /usr/local/lib/python3.5/dist-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# [2017-03-18 13:32:09,733] Starting new video recorder writing to /home/mimoralea/Projects/applied-reinforcement-learning/cartpole-experiment-1/openaigym.video.6.16738.video004000.mp4
# /usr/local/lib/python3.5/dist-packages/ipykernel/__main__.py:119: RuntimeWarning: Mean of empty slice.
# /usr/local/lib/python3.5/dist-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# [2017-03-18 13:32:11,914] Starting new video recorder writing to /home/mimoralea/Projects/applied-reinforcement-learning/cartpole-experiment-1/openaigym.video.6.16738.video005000.mp4
# /usr/local/lib/python3.5/dist-packages/ipykernel/__main__.py:119: RuntimeWarning: Mean of empty slice.
# /usr/local/lib/python3.5/dist-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# [2017-03-18 13:32:13,810] Starting new video recorder writing to /home/mimoralea/Projects/applied-reinforcement-learning/cartpole-experiment-1/openaigym.video.6.16738.video006000.mp4
# /usr/local/lib/python3.5/dist-packages/ipykernel/__main__.py:119: RuntimeWarning: Mean of empty slice.
# /usr/local/lib/python3.5/dist-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# [2017-03-18 13:32:16,226] Starting new video recorder writing to /home/mimoralea/Projects/applied-reinforcement-learning/cartpole-experiment-1/openaigym.video.6.16738.video007000.mp4
# /usr/local/lib/python3.5/dist-packages/ipykernel/__main__.py:119: RuntimeWarning: Mean of empty slice.
# /usr/local/lib/python3.5/dist-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# [2017-03-18 13:32:18,458] Starting new video recorder writing to /home/mimoralea/Projects/applied-reinforcement-learning/cartpole-experiment-1/openaigym.video.6.16738.video008000.mp4
# /usr/local/lib/python3.5/dist-packages/ipykernel/__main__.py:119: RuntimeWarning: Mean of empty slice.
# /usr/local/lib/python3.5/dist-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# [2017-03-18 13:32:20,016] Starting new video recorder writing to /home/mimoralea/Projects/applied-reinforcement-learning/cartpole-experiment-1/openaigym.video.6.16738.video009000.mp4
# /usr/local/lib/python3.5/dist-packages/ipykernel/__main__.py:119: RuntimeWarning: Mean of empty slice.
# /usr/local/lib/python3.5/dist-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# [2017-03-18 13:32:21,753] Starting new video recorder writing to /home/mimoralea/Projects/applied-reinforcement-learning/cartpole-experiment-1/openaigym.video.6.16738.video010000.mp4
# /usr/local/lib/python3.5/dist-packages/ipykernel/__main__.py:119: RuntimeWarning: Mean of empty slice.
# /usr/local/lib/python3.5/dist-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# [2017-03-18 13:32:23,950] Starting new video recorder writing to /home/mimoralea/Projects/applied-reinforcement-learning/cartpole-experiment-1/openaigym.video.6.16738.video011000.mp4
# /usr/local/lib/python3.5/dist-packages/ipykernel/__main__.py:119: RuntimeWarning: Mean of empty slice.
# /usr/local/lib/python3.5/dist-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# [2017-03-18 13:32:26,645] Starting new video recorder writing to /home/mimoralea/Projects/applied-reinforcement-learning/cartpole-experiment-1/openaigym.video.6.16738.video012000.mp4
# /usr/local/lib/python3.5/dist-packages/ipykernel/__main__.py:119: RuntimeWarning: Mean of empty slice.
# /usr/local/lib/python3.5/dist-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# [2017-03-18 13:32:28,257] Starting new video recorder writing to /home/mimoralea/Projects/applied-reinforcement-learning/cartpole-experiment-1/openaigym.video.6.16738.video013000.mp4
# /usr/local/lib/python3.5/dist-packages/ipykernel/__main__.py:119: RuntimeWarning: Mean of empty slice.
# /usr/local/lib/python3.5/dist-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# [2017-03-18 13:32:30,370] Starting new video recorder writing to /home/mimoralea/Projects/applied-reinforcement-learning/cartpole-experiment-1/openaigym.video.6.16738.video014000.mp4
# /usr/local/lib/python3.5/dist-packages/ipykernel/__main__.py:119: RuntimeWarning: Mean of empty slice.
# /usr/local/lib/python3.5/dist-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# [2017-03-18 13:32:32,501] Starting new video recorder writing to /home/mimoralea/Projects/applied-reinforcement-learning/cartpole-experiment-1/openaigym.video.6.16738.video015000.mp4
# /usr/local/lib/python3.5/dist-packages/ipykernel/__main__.py:119: RuntimeWarning: Mean of empty slice.
# /usr/local/lib/python3.5/dist-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# [2017-03-18 13:32:35,524] Starting new video recorder writing to /home/mimoralea/Projects/applied-reinforcement-learning/cartpole-experiment-1/openaigym.video.6.16738.video016000.mp4
# /usr/local/lib/python3.5/dist-packages/ipykernel/__main__.py:119: RuntimeWarning: Mean of empty slice.
# /usr/local/lib/python3.5/dist-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# [2017-03-18 13:32:37,162] Starting new video recorder writing to /home/mimoralea/Projects/applied-reinforcement-learning/cartpole-experiment-1/openaigym.video.6.16738.video017000.mp4
# /usr/local/lib/python3.5/dist-packages/ipykernel/__main__.py:119: RuntimeWarning: Mean of empty slice.
# /usr/local/lib/python3.5/dist-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# [2017-03-18 13:32:38,915] Starting new video recorder writing to /home/mimoralea/Projects/applied-reinforcement-learning/cartpole-experiment-1/openaigym.video.6.16738.video018000.mp4
# /usr/local/lib/python3.5/dist-packages/ipykernel/__main__.py:119: RuntimeWarning: Mean of empty slice.
# /usr/local/lib/python3.5/dist-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# [2017-03-18 13:32:40,989] Starting new video recorder writing to /home/mimoralea/Projects/applied-reinforcement-learning/cartpole-experiment-1/openaigym.video.6.16738.video019000.mp4
# /usr/local/lib/python3.5/dist-packages/ipykernel/__main__.py:119: RuntimeWarning: Mean of empty slice.
# /usr/local/lib/python3.5/dist-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# [2017-03-18 13:32:43,777] Starting new video recorder writing to /home/mimoralea/Projects/applied-reinforcement-learning/cartpole-experiment-1/openaigym.video.6.16738.video020000.mp4
# /usr/local/lib/python3.5/dist-packages/ipykernel/__main__.py:119: RuntimeWarning: Mean of empty slice.
# /usr/local/lib/python3.5/dist-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# [2017-03-18 13:32:45,544] Starting new video recorder writing to /home/mimoralea/Projects/applied-reinforcement-learning/cartpole-experiment-1/openaigym.video.6.16738.video021000.mp4
# /usr/local/lib/python3.5/dist-packages/ipykernel/__main__.py:119: RuntimeWarning: Mean of empty slice.
# /usr/local/lib/python3.5/dist-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# [2017-03-18 13:32:47,141] Starting new video recorder writing to /home/mimoralea/Projects/applied-reinforcement-learning/cartpole-experiment-1/openaigym.video.6.16738.video022000.mp4
# /usr/local/lib/python3.5/dist-packages/ipykernel/__main__.py:119: RuntimeWarning: Mean of empty slice.
# /usr/local/lib/python3.5/dist-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# [2017-03-18 13:32:48,819] Starting new video recorder writing to /home/mimoralea/Projects/applied-reinforcement-learning/cartpole-experiment-1/openaigym.video.6.16738.video023000.mp4
# /usr/local/lib/python3.5/dist-packages/ipykernel/__main__.py:119: RuntimeWarning: Mean of empty slice.
# /usr/local/lib/python3.5/dist-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# [2017-03-18 13:32:51,086] Starting new video recorder writing to /home/mimoralea/Projects/applied-reinforcement-learning/cartpole-experiment-1/openaigym.video.6.16738.video024000.mp4
# /usr/local/lib/python3.5/dist-packages/ipykernel/__main__.py:119: RuntimeWarning: Mean of empty slice.
# /usr/local/lib/python3.5/dist-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# [2017-03-18 13:32:52,984] Starting new video recorder writing to /home/mimoralea/Projects/applied-reinforcement-learning/cartpole-experiment-1/openaigym.video.6.16738.video025000.mp4
# /usr/local/lib/python3.5/dist-packages/ipykernel/__main__.py:119: RuntimeWarning: Mean of empty slice.
# /usr/local/lib/python3.5/dist-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# [2017-03-18 13:32:55,922] Starting new video recorder writing to /home/mimoralea/Projects/applied-reinforcement-learning/cartpole-experiment-1/openaigym.video.6.16738.video026000.mp4
# /usr/local/lib/python3.5/dist-packages/ipykernel/__main__.py:119: RuntimeWarning: Mean of empty slice.
# /usr/local/lib/python3.5/dist-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# [2017-03-18 13:32:58,771] Starting new video recorder writing to /home/mimoralea/Projects/applied-reinforcement-learning/cartpole-experiment-1/openaigym.video.6.16738.video027000.mp4
# /usr/local/lib/python3.5/dist-packages/ipykernel/__main__.py:119: RuntimeWarning: Mean of empty slice.
# /usr/local/lib/python3.5/dist-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# [2017-03-18 13:33:00,963] Starting new video recorder writing to /home/mimoralea/Projects/applied-reinforcement-learning/cartpole-experiment-1/openaigym.video.6.16738.video028000.mp4
# /usr/local/lib/python3.5/dist-packages/ipykernel/__main__.py:119: RuntimeWarning: Mean of empty slice.
# /usr/local/lib/python3.5/dist-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-5c9c46ffc351> in <module>()
#     128 if __name__ == "__main__":
#     129     random.seed(0)
# --> 130     cart_pole_with_qlearning()
#
# <ipython-input-12-5c9c46ffc351> in cart_pole_with_qlearning()
#     104
#     105             observation, reward, done, info = env.step(action)
# --> 106             cart_position, pole_angle, cart_velocity, angle_rate_of_change = observation
#     107
#     108             state_prime = build_state([to_bin(cart_position, cart_position_bins),
#
# KeyboardInterrupt:
